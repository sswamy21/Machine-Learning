# %% [markdown]
# <a href="https://colab.research.google.com/github/sswamy21/Machine-Learning/blob/main/notebook2e05dcbe8b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()
# Out:
# ...
# Kaggle credentials set.
# ...
# Kaggle credentials successfully validated.

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

march_machine_learning_mania_2026_path = kagglehub.competition_download('march-machine-learning-mania-2026')
print(march_machine_learning_mania_2026_path)
print('Data source import complete.')
# Out:
# /root/.cache/kagglehub/competitions/march-machine-learning-mania-2026
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# Load relevant datasets
mens_reg_season = pd.read_csv(f'{march_machine_learning_mania_2026_path}/MRegularSeasonDetailedResults.csv')
mens_tourney_seeds = pd.read_csv(f'{march_machine_learning_mania_2026_path}/MNCAATourneySeeds.csv')
mens_massey_ratings = pd.read_csv(f'{march_machine_learning_mania_2026_path}/MMasseyOrdinals.csv')
mens_tourney_results = pd.read_csv(f'{march_machine_learning_mania_2026_path}/MNCAATourneyCompactResults.csv')
mens_reg_season.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003      10     1104      68     1328      62    N      0    27    58
# 1    2003      10     1272      70     1393      63    N      0    26    62
# 2    2003      11     1266      73     1437      61    N      0    24    58
# 3    2003      11     1296      56     1457      50    N      0    18    38
# 4    2003      11     1400      77     1208      71    N      0    30    61
#
#    ...  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0  ...     10    16    22   10   22     8   18     9     2   20
# 1  ...     24     9    20   20   25     7   12     8     6   16
# 2  ...     26    14    23   31   22     9   12     2     5   23
# 3  ...     22     8    15   17   20     9   19     4     3   23
# 4  ...     16    17    27   21   15    12   10     7     1   14
#
# [5 rows x 34 columns]
# ...

# %%
# Only consider seasons after 2003
mens_tourney_seeds = mens_tourney_seeds[mens_tourney_seeds['Season'] >= 2003]
mens_massey_ratings = mens_massey_ratings[mens_massey_ratings['Season'] >= 2003]
mens_tourney_results = mens_tourney_results[mens_tourney_results['Season'] >= 2003]

# %%
# Split dataset on columns to find average stats for each team

# Define the base columns (things that apply to the whole game)
base_cols = ['Season']

# Identify the Winner and Loser specific columns
w_cols = [c for c in mens_reg_season.columns if c.startswith('W') and c != 'WLoc']
l_cols = [c for c in mens_reg_season.columns if c.startswith('L')]
